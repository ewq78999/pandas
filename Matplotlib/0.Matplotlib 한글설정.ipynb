# %% [markdown]
# # 한글폰트 설치

# %%
# 일단 import 
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %% [markdown]
# ## 한글 깨지는 것 확인하기

# %%
# 데이터 준비
import numpy as np

data = np.random.randint(-200, 100, 50).cumsum()
data
# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:93: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ewq78\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 시스템에 설치된 폰트 확인.

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

font = [f for f in sys_font if 'Nanum' in f]  #나눔폰트찾기
print(f"nanum_font number: {len(font)}")

font
# Out:
# sys_font number: 792
# ['C:\\Windows\\Fonts\\SF-Pro-Rounded-Medium.otf', 'C:\\Windows\\Fonts\\impact.ttf', 'C:\\Windows\\Fonts\\Candaral.ttf', 'C:\\Windows\\Fonts\\Gabriola.ttf', 'C:\\Windows\\Fonts\\SF-Pro-Text-Black.otf', 'C:\\Windows\\Fonts\\SF-Pro-Rounded-Heavy.otf', 'C:\\Windows\\Fonts\\ELEPHNT.TTF', 'C:\\Windows\\Fonts\\framdit.ttf', 'C:\\Windows\\Fonts\\BaskervilleMTStd-BoldIt.otf', 'C:\\Windows\\Fonts\\cambriaz.ttf', 'C:\\Windows\\Fonts\\FRAHV.TTF', 'C:\\Windows\\Fonts\\BodoniStd-BookItalic.otf', 'C:\\Windows\\Fonts\\unl____.ttf', 'C:\\Windows\\Fonts\\javatext.ttf', 'C:\\Windows\\Fonts\\SMSEMyungJoStd-Regular.otf', 'C:\\Windows\\Fonts\\NanumSquareL.ttf', 'C:\\Windows\\Fonts\\BauerBodoniStd-BlackCond.otf', 'C:\\Windows\\Fonts\\unispace bd.ttf', 'C:\\Windows\\Fonts\\GaramondPremrPro-MedIt.otf', 'C:\\Windows\\Fonts\\COOPBL.TTF', 'C:\\Windows\\Fonts\\ALGER.TTF', 'C:\\Windows\\Fonts\\GaramondPremrPro-BdDisp.otf', 'C:\\Windows\\Fonts\\BodoniStd-BoldItalic.otf', 'C:\\Windows\\Fonts\\PixelOperator8-Bold.ttf', 'C:\\Windows\\Fonts\\ARIALN.TTF', 'C:\\Windows\\Fonts\\seguisb.ttf', 'C:\\Windows\\Fonts\\GOTHICBI.TTF', 'C:\\Windows\\Fonts\\TCM_____.TTF', 'C:\\Windows\\Fonts\\FRAHVIT.TTF', 'C:\\Windows\\Fonts\\BELLI.TTF', 'C:\\Windows\\Fonts\\Helvetica Ultra Compressed.ttf', 'C:\\Windows\\Fonts\\-윤고딕530.ttf', 'C:\\Windows\\Fonts\\ANTQUABI.TTF', 'C:\\Windows\\Fonts\\ClarendonLTStd.otf', 'C:\\Windows\\Fonts\\PixelOperatorSC.ttf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\SB 어그로 L.ttf', 'C:\\Windows\\Fonts\\arialbi.ttf', 'C:\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-ligature.ttf', 'C:\\Windows\\Fonts\\futura light bt.ttf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMYEONSUNG_ttf.ttf', 'C:\\Windows\\Fonts\\ClarendonLTStd-Light.otf', 'C:\\Windows\\Fonts\\ANTQUAB.TTF', 'C:\\Windows\\Fonts\\SF-Pro-Display-Bold.otf', 'C:\\Windows\\Fonts\\NIAGENG.TTF', 'C:\\Windows\\Fonts\\MATURASC.TTF', 'C:\\Windows\\Fonts\\SUIT-Heavy.ttf', 'C:\\Windows\\Fonts\\FTLTLT.TTF', 'C:\\Windows\\Fonts\\CooperHewitt-ThinItalic.otf', 'C:\\Windows\\Fonts\\segmdl2.ttf', 'C:\\Windows\\Fonts\\SMGMokPanStd-Regular.otf', 'C:\\Windows\\Fonts\\BodoniStd-Italic.otf', 'C:\\Windows\\Fonts\\AppleSDGothicNeoUL.ttf', 'C:\\Windows\\Fonts\\BRADHITC.TTF', 'C:\\Windows\\Fonts\\UniversLTStd-XBlackEx.otf', 'C:\\Windows\\Fonts\\UniversLTStd-BoldObl.otf', 'C:\\Windows\\Fonts\\POORICH.TTF', 'C:\\Windows\\Fonts\\CENTURY.TTF', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\dalmoori.ttf', 'C:\\Windows\\Fonts\\SCHLBKBI.TTF', 'C:\\Windows\\Fonts\\GILSANUB.TTF', 'C:\\Windows\\Fonts\\H2MJSM.TTF', 'C:\\Windows\\Fonts\\SMSMyungJoStd-Regular.otf', 'C:\\Windows\\Fonts\\MISTRAL.TTF', 'C:\\Windows\\Fonts\\Helvetica Narrow Bold Oblique.ttf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\AppleSDGothicNeoM.ttf', 'C:\\Windows\\Fonts\\GaramondPremrPro-Bd.otf', 'C:\\Windows\\Fonts\\Helvetica Extended Thin.ttf', 'C:\\Windows\\Fonts\\GaramondPremrPro-SmbdSubh.otf', 'C:\\Windows\\Fonts\\MSUIGHUR.TTF', 'C:\\Windows\\Fonts\\Candarai.ttf', 'C:\\Windows\\Fonts\\UniversLTStd-ThinUltraCn.otf', 'C:\\Windows\\Fonts\\Helvetica Rounded Bold.ttf', 'C:\\Windows\\Fonts\\PixelOperatorMonoHB8.ttf', 'C:\\Windows\\Fonts\\segoeuisl.ttf', 'C:\\Windows\\Fonts\\FRADMIT.TTF', 'C:\\Windows\\Fonts\\Helvetica Extended Heavy.ttf', 'C:\\Windows\\Fonts\\RIXGOEB.TTF', 'C:\\Windows\\Fonts\\MAIAN.TTF', 'C:\\Windows\\Fonts\\NanumSquareRoundL.ttf', 'C:\\Windows\\Fonts\\Hancom Gothic Bold.ttf', 'C:\\Windows\\Fonts\\georgiaz.ttf', 'C:\\Windows\\Fonts\\UniversLTStd-BoldCn.otf', 'C:\\Windows\\Fonts\\GaramondPremrPro-Disp.otf', 'C:\\Windows\\Fonts\\palabi.ttf', 'C:\\Windows\\Fonts\\BaskervilleMTStd-Italic.otf', 'C:\\Windows\\Fonts\\LSANSDI.TTF', 'C:\\Windows\\Fonts\\UniversLTStd-BlackExObl.otf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BemboStd.otf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Azonix.otf', 'C:\\Windows\\Fonts\\calibrili.ttf', 'C:\\Windows\\Fonts\ ...
# nanum_font number: 25
# ['C:\\Windows\\Fonts\\NanumSquareL.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundL.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareR.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjo-YetHangul.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicUltraLight.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareB.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothic-YetHangul.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicLight.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundEB.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareEB.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenR.ttf',
#  'C:\\Windows\\Fonts\\NanumGothic.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicBold.ttf',
#  'C:\\Windows\\Fonts\\NanumPen.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothic.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicBold.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjoBold.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundB.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundR.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenB.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicLight.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjo.ttf',
#  'C:\\Windows\\Fonts\\NanumBrush.ttf']

# %%
font = [f for f in sys_font if 'malgun' in f]  #맑은폰트찾기
print(f"Malgun_font number: {len(font)}")
font
# Out:
# Malgun_font number: 3
# ['C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf']

# %% [markdown]
# ## matplotlib 글꼴 패밀리 검색

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#메모리 상에 현재 설정되어 있는 폰트 패밀리 이름
font_family = plt.rcParams['font.family']
font_family
# Out:
# ['sans-serif']

# %%
#맷플랏립의 기본 글꼴-> 한글표현 안 되겠쥬
fm.FontManager().defaultFont
# Out:
# Matplotlib is building the font cache; this may take a moment.
# {'ttf': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf',
#  'afm': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\pdfcorefonts\\Helvetica.afm'}

# %%
# matplotlib 한글 폰트 오류 문제 해결 

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

#폰트파일위치 지정해서 설정
font_path = 'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()

#폰트 설정
plt.rc('font', family=font_name)

# 마이너스 깨짐 현상 해결
plt.rcParams['axes.unicode_minus'] = False

# matplotlib 폰트 패밀리 출력
plt.rcParams['font.family']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Dev_camp29\Matplotlib\0.Matplotlib 한글설정.ipynb 셀 11 line 8
#       <a href='vscode-notebook-cell:/c%3A/Dev_camp29/Matplotlib/0.Matplotlib%20%ED%95%9C%EA%B8%80%EC%84%A4%EC%A0%95.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> #폰트파일위치 지정해서 설정
#       <a href='vscode-notebook-cell:/c%3A/Dev_camp29/Matplotlib/0.Matplotlib%20%ED%95%9C%EA%B8%80%EC%84%A4%EC%A0%95.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> font_path = 'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf'
# ----> <a href='vscode-notebook-cell:/c%3A/Dev_camp29/Matplotlib/0.Matplotlib%20%ED%95%9C%EA%B8%80%EC%84%A4%EC%A0%95.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> font_name = fm.FontProperties(fname=font_path).get_name()
#      <a href='vscode-notebook-cell:/c%3A/Dev_camp29/Matplotlib/0.Matplotlib%20%ED%95%9C%EA%B8%80%EC%84%A4%EC%A0%95.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> #폰트 설정
#      <a href='vscode-notebook-cell:/c%3A/Dev_camp29/Matplotlib/0.Matplotlib%20%ED%95%9C%EA%B8%80%EC%84%A4%EC%A0%95.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> plt.rc('font', family=font_name)
#
# File c:\Python\python310\lib\site-packages\matplotlib\font_manager.py:664, in FontProperties.get_name(self)
#     660 def get_name(self):
#     661     """
#     662     Return the name of the font that best matches the font properties.
#     663     """
# --> 664     return get_font(findfont(self)).family_name
#
# File c:\Python\python310\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Python\python310\lib\site-packages\matplotlib\font_manager.py:1523, in get_font(font_filepaths, hinting_factor)
#    1520 if hinting_factor is None:
#    1521     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1523 return _get_font(
#    1524     # must be a tuple to be cached
#    1525     paths,
#    1526     hinting_factor,
#    1527     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1528     # also key on the thread ID to prevent segfaults with multi-threading
#    1529     thread_id=threading.get_ident()
#    1530 )
#
# File c:\Python\python310\lib\site-packages\matplotlib\font_manager.py:1464, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1461 @lru_cache(64)
#    1462 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1463     first_fontpath, *rest = font_filepaths
# -> 1464     return ft2font.FT2Font(
#    1465         first_fontpath, hinting_factor,
#    1466         _fallback_list=[
#    1467             ft2font.FT2Font(
#    1468                 fpath, hinting_factor,
#    1469                 _kerning_factor=_kerning_factor
#    1470             )
#    1471             for fpath in rest
#    1472         ],
#    1473         _kerning_factor=_kerning_factor
#    1474     )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\miran\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquare.ttf'

# %%
# 데이터 준비
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl  # 기본 설정 만지는 용도

data = np.random.randint(-200, 100, 50).cumsum()
data

## 폰트 설정 및 마이너스 부호 설정
plt.rc('font', family='NanumSquare') #나눔 글꼴로 설정
#plt.rc('font', family='Malgun Gothic') #맑은 고딕으로 설정
#plt.rc('font', family='AppleGothic') #맥
plt.rcParams['axes.unicode_minus'] = False #부호


# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
