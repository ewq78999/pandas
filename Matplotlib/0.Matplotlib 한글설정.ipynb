# %% [markdown]
# # 한글폰트 설치

# %%
# 일단 import 
# %matplotlib inline  

import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %% [markdown]
# ## 한글 깨지는 것 확인하기

# %%
# 데이터 준비
import numpy as np

data = np.random.randint(-200, 100, 50).cumsum()
data
# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')

# matplotlib 한글 폰트 오류 문제 해결해서 깨지는 현상 고침!
# Out:
# Text(0.5, 0, '시간(분)')

# %% [markdown]
# ## 시스템에 설치된 폰트 확인.

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

font = [f for f in sys_font if 'Nanum' in f]  #나눔폰트찾기
print(f"nanum_font number: {len(font)}")

font
# Out:
# sys_font number: 792
# ['C:\\Windows\\Fonts\\JUMJA.TTF', 'C:\\Windows\\Fonts\\ITCKRIST.TTF', 'C:\\Windows\\Fonts\\PixelOperatorMono.ttf', 'C:\\Windows\\Fonts\\mmrtextb.ttf', 'C:\\Windows\\Fonts\\unispace bd.ttf', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\BMHANNAPro.ttf', 'C:\\Windows\\Fonts\\consola.ttf', 'C:\\Windows\\Fonts\\CooperHewitt-Light.otf', 'C:\\Windows\\Fonts\\Futura Bold font.ttf', 'C:\\Windows\\Fonts\\LBRITEDI.TTF', 'C:\\Windows\\Fonts\\framdit.ttf', 'C:\\Windows\\Fonts\\courbi.ttf', 'C:\\Windows\\Fonts\\msyhl.ttc', 'C:\\Windows\\Fonts\\segoeuil.ttf', 'C:\\Windows\\Fonts\\AppleSDGothicNeoR.ttf', 'C:\\Windows\\Fonts\\Candarab.ttf', 'C:\\Windows\\Fonts\\UniversLTStd-BoldEx.otf', 'C:\\Windows\\Fonts\\LCALLIG.TTF', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\비트로 코어 TTF.ttf', 'C:\\Windows\\Fonts\\NirmalaS.ttf', 'C:\\Windows\\Fonts\\GaramondPremrPro-MedIt.otf', 'C:\\Windows\\Fonts\\SF-Pro-Rounded-Thin.otf', 'C:\\Windows\\Fonts\\segoeprb.ttf', 'C:\\Windows\\Fonts\\Helvetica Condensed.ttf', 'C:\\Windows\\Fonts\\RIXGOB.TTF', 'C:\\Windows\\Fonts\\GaramondPremrPro-Med.otf', 'C:\\Windows\\Fonts\\BauerBodoniStd-BlackItalic.otf', 'C:\\Windows\\Fonts\\ROCKB.TTF', 'C:\\Windows\\Fonts\\GaramondPremrPro-MedSubh.otf', 'C:\\Windows\\Fonts\\msyhbd.ttc', 'C:\\Windows\\Fonts\\trebucbi.ttf', 'C:\\Windows\\Fonts\\SMTGothicStd-Regular.otf', 'C:\\Windows\\Fonts\\segoeuib.ttf', 'C:\\Windows\\Fonts\\Helvetica Rounded Bold.ttf', 'C:\\Windows\\Fonts\\Futura Book Italic font.ttf', 'C:\\Windows\\Fonts\\H2GPRM.TTF', 'C:\\Windows\\Fonts\\CALIFI.TTF', 'C:\\Windows\\Fonts\\msjhl.ttc', 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\
 'C:\\Users\\ewq78\\AppData\\Local\\Microsoft\\Windows\\Fonts\\LEVIBRUSH.TTF', 'C:\\Windows\\Fonts\\LeelaUIb.ttf', 'C:\\Windows\\Fonts\\BaskervilleMTStd-Italic.otf', 'C:\\Windows\\Fonts\\Helvetica Extended Thin.ttf', 'C:\\Windows\\Fonts\\SF-Pro-Display-Black.otf', 'C:\\Windows\\Fonts\\IMPRISHA.TTF', 'C:\\Windows ...
# nanum_font number: 25
# ['C:\\Windows\\Fonts\\NanumGothicExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundR.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenR.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundEB.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundB.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicUltraLight.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareRoundL.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothic.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjo-YetHangul.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicLight.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothicBold.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareB.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareEB.ttf',
#  'C:\\Windows\\Fonts\\NanumGothic.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicLight.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjoBold.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunGothic-YetHangul.ttf',
#  'C:\\Windows\\Fonts\\NanumPen.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareL.ttf',
#  'C:\\Windows\\Fonts\\NanumBarunpenB.ttf',
#  'C:\\Windows\\Fonts\\NanumGothicBold.ttf',
#  'C:\\Windows\\Fonts\\NanumSquareR.ttf',
#  'C:\\Windows\\Fonts\\NanumMyeongjo.ttf',
#  'C:\\Windows\\Fonts\\NanumBrush.ttf']

# %%
font = [f for f in sys_font if 'malgun' in f]  #맑은폰트찾기
print(f"Malgun_font number: {len(font)}")
font
# Out:
# Malgun_font number: 3
# ['C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf']

# %% [markdown]
# ## matplotlib 글꼴 패밀리 검색

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#메모리 상에 현재 설정되어 있는 폰트 패밀리 이름
font_family = plt.rcParams['font.family']
font_family
# Out:
# ['sans-serif']

# %%
#맷플랏립의 기본 글꼴-> 한글표현 안 되겠쥬
fm.FontManager().defaultFont
# Out:
# Matplotlib is building the font cache; this may take a moment.
# {'ttf': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf',
#  'afm': 'C:\\Python\\python310\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\pdfcorefonts\\Helvetica.afm'}

# %%
# matplotlib 한글 폰트 오류 문제 해결 

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

#폰트파일위치 지정해서 설정
font_path = 'C:\\Windows\\Fonts\\NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()

#폰트 설정
plt.rc('font', family=font_name)

# 마이너스 깨짐 현상 해결
plt.rcParams['axes.unicode_minus'] = False

# matplotlib 폰트 패밀리 출력
plt.rcParams['font.family']
# Out:
# ['NanumGothic']

# %%
# 데이터 준비
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl  # 기본 설정 만지는 용도

data = np.random.randint(-200, 100, 50).cumsum()
data

## 폰트 설정 및 마이너스 부호 설정
plt.rc('font', family='NanumSquare') #나눔 글꼴로 설정 -> 시스템에 글꼴 설치했을 경우 로드
#plt.rc('font', family='Malgun Gothic') #맑은 고딕으로 설정
#plt.rc('font', family='AppleGothic') #맥
plt.rcParams['axes.unicode_minus'] = False #부호


# 한글을 넣어놓고 그러보면 깨진다
plt.figure(figsize=(6,4))
plt.plot(range(50), data, 'r')
plt.title('시간별 가격추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')
